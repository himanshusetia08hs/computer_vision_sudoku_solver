# %% [markdown]
# # CGANs - Conditional Generative Adversarial Nets
#
# Brief introduction to Conditional Generative Adversarial Nets or CGANs. This notebook is organized as follows:
#
# 1. **Research Paper**
# * **Background**
# * **Definition**
# * **Training CGANs with MNIST dataset, Keras and TensorFlow**

# %% [markdown]
# ## 1. Research Paper
#
# * [Conditional Generative Adversarial Nets](https://arxiv.org/pdf/1411.1784.pdf)
#
# ## 2. Background
#
# **Generative adversarial nets** consists of two models: a generative model $G$ that captures the data distribution, and a discriminative model $D$ that estimates the probability that a sample came from the training data rather than $G$.
#
# The generator distribution $p_g$ over data data $x$, the generator builds a mapping function from a prior noise distribution $p_z(z)$ to data space as $G(z;\theta_g)$.
#
# The discriminator, $D(x;\theta_d)$, outputs a single scalar representing the probability that $x$ came form training data rather than $p_g$.
#
# The **value function** $V(G,D)$:
#
# $$ \underset{G}{min} \: \underset{D}{max} \; V_{GAN}(D,G) = \mathbb{E}_{x\sim p_{data}(x)}[log D(x)] + \mathbb{E}_{z\sim p_{z}(z)}[log(1 - D(G(z)))]$$

# %% [markdown]
# ## 3. Definition
#
# Generative adversarial nets can be extended to a **conditional model** if both the generator and discriminator are conditioned on some extra information $y$.
#
# * $y$ could be any kind of auxiliary information, such as class labels or data from other modalities.
#
# We can perform the conditioning by feeding $y$ into the both the discriminator and generator as additional input layer.
#
# * **Generator**: The prior input noise $p_z(z)$, and $y$ are combined in joint hidden representation, and the adversarial training framework allows for considerable flexibility in how this hidden representation is composed.
#
# * **Discriminator**: $x$ and $y$ are presented as inputs and to a discriminative function.
#
# ### Network Design
#
# <img src="../../img/network_design_ccgan.png" width="600">
#
#
# ### Cost Funcion
#
# $$ \underset{G}{min} \: \underset{D}{max} \; V_{CGAN}(D,G) = \mathbb{E}_{x\sim p_{data}(x)}[log D(x|y)] + \mathbb{E}_{z\sim p_{z}(z)}[log(1 - D(G(z|y)))]$$

# %% [markdown]
# ## 4. Training CGANs with MNIST dataset, Keras and TensorFlow
#
# CGANs implementation using fully connected and embedding layers and the [Keras](https://keras.io/) library.
#
# * **Data**
#     * Rescale the MNIST images to be between -1 and 1.
#
# * **Generator**
#     * **Simple fully connected neural network**, **LeakyReLU activation** and **BatchNormalization**.
#     * The input to the generator are the **normal distribution** $z$ and $y$. They are combined in joint hidden representation.
#         * Embedding($y, z$).
#     * The last activation is **tanh**.
#
# * **Discriminator**
#     * **Simple fully connected neural network** and **LeakyReLU activation**.
#     * The input to the discriminator are $x$ and $y$. They are combined in joint hidden representation.
#         *  Embedding($y, x$).
#     * The last activation is **sigmoid**.
#
# * **Loss**
#     * binary_crossentropy
#
# * **Optimizer**
#     * Adam(lr=0.0002, beta_1=0.5)
#
# * batch_size = 64
# * epochs = 100
#
# ### 1. Load data
#
# #### Load libraries

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from keras.datasets import mnist
from keras.models import Sequential, Model
from keras.layers import Dense, LeakyReLU, BatchNormalization
from keras.layers import Input, Flatten, Embedding, multiply, Dropout
from tensorflow.keras.optimizers import Adam
from keras import initializers

# %% [markdown]
# ---
# #### Embedding layer background

# %%
model = Sequential()
model.add(Embedding(10, 2))
# the model will take as input an integer matrix of size (batch, input_length).
# the largest integer (i.e. word index) in the input should be no larger than 999 (vocabulary size).
# now model.output_shape == (None, 10, 64), where None is the batch dimension.

# input_array = np.random.randint(10, size=(1, 10))
input_array = np.arange(0, 10).reshape(1, -1)
model.compile('rmsprop', 'mse')
output_array = model.predict(input_array)
print(output_array)
# print(output_array.shape)
plt.scatter(output_array[0, :, 0], output_array[0, :, 1])
# Out:
# [[[ 0.02044963  0.02616658]
#   [ 0.03774262 -0.02307314]
#   [ 0.04283786  0.01499964]
#   [-0.0042941   0.03605821]
#   [-0.0404576  -0.02094426]
#   [-0.01180414 -0.02941092]
#   [-0.04779146  0.02566446]
#   [ 0.03985193 -0.01331768]
#   [ 0.01246666 -0.00908811]
#   [ 0.0274732   0.04062044]]]

# %% [markdown]
# ---
# #### Getting the data

# %%
# load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# #### Explore visual data

# %%
fig = plt.figure()
for i in range(10):
    plt.subplot(2, 5, i+1)
    x_y = X_train[y_train == i]
    plt.imshow(x_y[0], cmap='gray', interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])
    
plt.tight_layout()

# %% [markdown]
# #### Reshaping and normalizing the inputs

# %%
print('X_train.shape', X_train.shape)
print('y_train.shape', y_train.shape)

# reshaping the inputs
X_train = X_train.reshape(60000, 28*28)
# normalizing the inputs (-1, 1)
X_train = (X_train.astype('float32') / 255 - 0.5) * 2

print('X_train reshape:', X_train.shape)
# Out:
# X_train.shape (60000, 28, 28)
# y_train.shape (60000,)
# X_train reshape: (60000, 784)

# %% [markdown]
# ### 2. Define model
#
# #### Generator

# %%
# latent space dimension
latent_dim = 100

# imagem dimension 28x28
img_dim = 784

init = initializers.RandomNormal(stddev=0.02)

# Generator network
generator = Sequential()

# Input layer and hidden layer 1
generator.add(Dense(128, input_shape=(latent_dim,), kernel_initializer=init))
generator.add(LeakyReLU(alpha=0.2))
generator.add(BatchNormalization(momentum=0.8))

# Hidden layer 2
generator.add(Dense(256))
generator.add(LeakyReLU(alpha=0.2))
generator.add(BatchNormalization(momentum=0.8))

# Hidden layer 3
generator.add(Dense(512))
generator.add(LeakyReLU(alpha=0.2))
generator.add(BatchNormalization(momentum=0.8))

# Output layer 
generator.add(Dense(img_dim, activation='tanh'))

# %% [markdown]
# #### Generator model visualization

# %%
# prints a summary representation of your model
generator.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               12928
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_9 (Dense)             (None, 256)               33024
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_10 (Dense)            (None, 512)               131584
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_11 (Dense)            (None, 784)               402192
#
# =================================================================
# Total params: 583,312
# Trainable params: 581,520
# Non-trainable params: 1,792
# _________________________________________________________________

# %% [markdown]
# #### Conditional G model
# The prior input noise $p_z(z)$, and $y$ are combined in joint hidden representation.

# %%
# Embedding condition in input layer
num_classes = 10

# Create label embeddings
label = Input(shape=(1,), dtype='int32')
label_embedding = Embedding(num_classes, latent_dim)(label)
label_embedding = Flatten()(label_embedding)

# latent space
z = Input(shape=(latent_dim,))

# Merge inputs (z x label)
input_generator = multiply([z, label_embedding])

# Output image
img = generator(input_generator)

# Generator with condition input
generator = Model([z, label], img)

# %% [markdown]
# #### Conditional model visualization

# %%
# prints a summary representation of your model
generator.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 1)]          0           []
#
#  embedding_4 (Embedding)        (None, 1, 100)       1000        ['input_5[0][0]']
#
#  input_6 (InputLayer)           [(None, 100)]        0           []
#
#  flatten_2 (Flatten)            (None, 100)          0           ['embedding_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 100)          0           ['input_6[0][0]',
#                                                                   'flatten_2[0][0]']
#
#  sequential_4 (Sequential)      (None, 784)          583312      ['multiply_2[0][0]']
#
# ==================================================================================================
# Total params: 584,312
# Trainable params: 582,520
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# #### Discriminator

# %%
# Discriminator network
discriminator = Sequential()

# Input layer and hidden layer 1
discriminator.add(Dense(128, input_shape=(img_dim,), kernel_initializer=init))
discriminator.add(LeakyReLU(alpha=0.2))

# Hidden layer 2
discriminator.add(Dense(256))
discriminator.add(LeakyReLU(alpha=0.2))

# Hidden layer 3
discriminator.add(Dense(512))
discriminator.add(LeakyReLU(alpha=0.2))

# Output layer
discriminator.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# #### Discriminator model visualization

# %%
# prints a summary representation of your model
discriminator.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               100480
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 128)               0
#
#  dense_13 (Dense)            (None, 256)               33024
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 256)               0
#
#  dense_14 (Dense)            (None, 512)               131584
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 512)               0
#
#  dense_15 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 265,601
# Trainable params: 265,601
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Conditional D model
#
# $x$ and $y$ are presented as inputs

# %%
# Embedding condition in input layer

# Create label embeddings
label_d = Input(shape=(1,), dtype='int32')
label_embedding_d = Embedding(num_classes, img_dim)(label_d)
label_embedding_d = Flatten()(label_embedding_d)

# imagem dimension 28x28
img_d = Input(shape=(img_dim,))

# Merge inputs (img x label)
input_discriminator = multiply([img_d, label_embedding_d])

# Output image
validity = discriminator(input_discriminator)

# Discriminator with condition input
discriminator = Model([img_d, label_d], validity)

# %% [markdown]
# #### Conditional model visualization

# %%
# prints a summary representation of your model
discriminator.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 1)]          0           []
#
#  embedding_5 (Embedding)        (None, 1, 784)       7840        ['input_7[0][0]']
#
#  input_8 (InputLayer)           [(None, 784)]        0           []
#
#  flatten_3 (Flatten)            (None, 784)          0           ['embedding_5[0][0]']
#
#  multiply_3 (Multiply)          (None, 784)          0           ['input_8[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  sequential_5 (Sequential)      (None, 1)            265601      ['multiply_3[0][0]']
#
# ==================================================================================================
# Total params: 273,441
# Trainable params: 273,441
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 3. Compile model

# %% [markdown]
# #### Compile discriminator

# %%
# Optimizer
optimizer = Adam(learning_rate=0.0002, beta_1=0.5)

discriminator.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'])

# %% [markdown]
# #### Combined network

# %%
discriminator.trainable = False

validity = discriminator([generator([z, label]), label])

d_g = Model([z, label], validity)

d_g.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
# prints a summary representation of your model
d_g.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 100)]        0           []
#
#  input_5 (InputLayer)           [(None, 1)]          0           []
#
#  model_3 (Functional)           (None, 784)          584312      ['input_6[0][0]',
#                                                                   'input_5[0][0]']
#
#  model_4 (Functional)           (None, 1)            273441      ['model_3[0][0]',
#                                                                   'input_5[0][0]']
#
# ==================================================================================================
# Total params: 857,753
# Trainable params: 582,520
# Non-trainable params: 275,233
# __________________________________________________________________________________________________

# %% [markdown]
# ### 4. Fit model

# %%
epochs = 100
batch_size = 64
smooth = 0.1

real = np.ones(shape=(batch_size, 1))
fake = np.zeros(shape=(batch_size, 1))

d_loss = []
d_g_loss = []

for e in range(epochs + 1):
    for i in range(len(X_train) // batch_size):
        
        # Train Discriminator weights
        discriminator.trainable = True
        
        # Real samples
        X_batch = X_train[i*batch_size:(i+1)*batch_size]
        real_labels = y_train[i*batch_size:(i+1)*batch_size].reshape(-1, 1)
        
        d_loss_real = discriminator.train_on_batch(x=[X_batch, real_labels], y=real * (1 - smooth))
        
        # Fake Samples
        z = np.random.normal(loc=0, scale=1, size=(batch_size, latent_dim))
        random_labels = np.random.randint(0, 10, batch_size).reshape(-1, 1)
        X_fake = generator.predict_on_batch([z, random_labels])
        
        d_loss_fake = discriminator.train_on_batch(x=[X_fake, random_labels], y=fake)
         
        # Discriminator loss
        d_loss_batch = 0.5 * (d_loss_real[0] + d_loss_fake[0])
        
        # Train Generator weights
        discriminator.trainable = False
        
        z = np.random.normal(loc=0, scale=1, size=(batch_size, latent_dim))
        random_labels = np.random.randint(0, 10, batch_size).reshape(-1, 1)
        d_g_loss_batch = d_g.train_on_batch(x=[z, random_labels], y=real)
   
        print(
            'epoch = %d/%d, batch = %d/%d, d_loss=%.3f, g_loss=%.3f' % (e + 1, epochs, i, len(X_train) // batch_size, d_loss_batch, d_g_loss_batch[0]),
            100*' ',
            end='\r'
        )
    
    d_loss.append(d_loss_batch)
    d_g_loss.append(d_g_loss_batch[0])
    print('epoch = %d/%d, d_loss=%.3f, g_loss=%.3f' % (e + 1, epochs, d_loss[-1], d_g_loss[-1]), 100*' ')

    if e % 10 == 0:
        samples = 10
        z = np.random.normal(loc=0, scale=1, size=(samples, latent_dim))
        labels = np.arange(0, 10).reshape(-1, 1)
        
        x_fake = generator.predict([z, labels])

        for k in range(samples):
            plt.subplot(2, 5, k+1)
            plt.imshow(x_fake[k].reshape(28, 28), cmap='gray')
            plt.xticks([])
            plt.yticks([])

        plt.tight_layout()
        plt.show()
# Out:
# epoch = 1/100, d_loss=0.695, g_loss=0.889
# epoch = 2/100, d_loss=0.684, g_loss=0.804
# epoch = 3/100, d_loss=0.671, g_loss=0.827
# epoch = 4/100, d_loss=0.686, g_loss=0.821
# epoch = 5/100, d_loss=0.668, g_loss=0.823
# epoch = 6/100, d_loss=0.663, g_loss=0.809
# epoch = 7/100, d_loss=0.665, g_loss=0.798
# epoch = 8/100, d_loss=0.665, g_loss=0.813
# epoch = 9/100, d_loss=0.669, g_loss=0.810
# epoch = 10/100, d_loss=0.672, g_loss=0.794
# epoch = 11/100, d_loss=0.659, g_loss=0.821
# epoch = 12/100, d_loss=0.686, g_loss=0.817
# epoch = 13/100, d_loss=0.649, g_loss=0.793
# epoch = 14/100, d_loss=0.655, g_loss=0.841
# epoch = 15/100, d_loss=0.662, g_loss=0.818
# epoch = 16/100, d_loss=0.652, g_loss=0.817 52, g_loss=0.817
# epoch = 17/100, d_loss=0.648, g_loss=0.806
# epoch = 18/100, d_loss=0.655, g_loss=0.867
# epoch = 19/100, d_loss=0.660, g_loss=0.827
# epoch = 20/100, d_loss=0.648, g_loss=0.872
# epoch = 21/100, d_loss=0.652, g_loss=0.872
# epoch = 22/100, d_loss=0.654, g_loss=0.888
# epoch = 23/100, d_loss=0.671, g_loss=0.821
# epoch = 24/100, d_loss=0.667, g_loss=0.858
# epoch = 25/100, d_loss=0.658, g_loss=0.857
# epoch = 26/100, d_loss=0.682, g_loss=0.857
# epoch = 27/100, d_loss=0.670, g_loss=0.895
# epoch = 28/100, d_loss=0.647, g_loss=0.877
# epoch = 29/100, d_loss=0.665, g_loss=0.883
# epoch = 30/100, d_loss=0.663, g_loss=0.864
# epoch = 31/100, d_loss=0.666, g_loss=0.883
# epoch = 32/100, d_loss=0.649, g_loss=0.857
# epoch = 33/100, d_loss=0.663, g_loss=0.882
# epoch = 34/100, d_loss=0.657, g_loss=0.850
# epoch = 35/100, d_loss=0.666, g_loss=0.883
# epoch = 36/100, d_loss=0.665, g_loss=0.899
# epoch = 37/100, d_loss=0.665, g_loss=0.880
# epoch = 38/100, d_loss=0.636, g_loss=0.847
# epoch = 39/100, d_loss=0.640, g_loss=0.852
# epoch = 40/100, d_loss=0.656, g_loss=0.842
# epoch = 41/100, d_loss=0.656, g_loss=0.844
# epoch = 42/100, d_loss=0.612, g_loss=0.859
# epoch = 43/100, d_loss=0.660, g_loss=0.855
# epoch = 44/100, d_loss=0.627, g_loss=0.846
# epoch = 45/100, d_loss=0.667, g_loss=0.862
# epoch = 46/100, d_loss=0.670, g_loss=0.880
# epoch = 47/100, d_loss=0.661, g_loss=0.843
# epoch = 48/100, d_loss=0.666, g_loss=0.836
# epoch = 49/100, d_loss=0.644, g_loss=0.860
# epoch = 50/100, d_loss=0.652, g_loss=0.838
# epoch = 51/100, d_loss=0.677, g_loss=0.903
# epoch = 52/100, d_loss=0.654, g_loss=0.876
# epoch = 53/100, d_loss=0.672, g_loss=0.867
# epoch = 54/100, d_loss=0.632, g_loss=0.872
# epoch = 55/100, d_loss=0.654, g_loss=0.850
# epoch = 56/100, d_loss=0.633, g_loss=0.832
# epoch = 57/100, d_loss=0.670, g_loss=0.884
# epoch = 58/100, d_loss=0.655, g_loss=0.850
# epoch = 59/100, d_loss=0.657, g_loss=0.869
# epoch = 60/100, d_loss=0.661, g_loss=0.846
# epoch = 61/100, d_loss=0.636, g_loss=0.877
# epoch = 62/100, d_loss=0.651, g_loss=0.847
# epoch = 63/100, d_loss=0.646, g_loss=0.852
# epoch = 64/100, d_loss=0.683, g_loss=0.890
# epoch = 65/100, d_loss=0.637, g_loss=0.901
# epoch = 66/100, d_loss=0.666, g_loss=0.845
# epoch = 67/100, d_loss=0.639, g_loss=0.902
# epoch = 68/100, d_loss=0.637, g_loss=0.855
# epoch = 69/100, d_loss=0.646, g_loss=0.866
# epoch = 70/100, d_loss=0.656, g_loss=0.904
# epoch = 71/100, d_loss=0.645, g_loss=0.878
# epoch = 72/100, d_loss=0.647, g_loss=0.859
# epoch = 73/100, d_loss=0.643, g_loss=0.887
# epoch = 74/100, d_loss=0.648, g_loss=0.886
# epoch = 75/100, d_loss=0.666, g_loss=0.863
# epoch = 76/100, d_loss=0.637, g_loss=0.903
# epoch = 77/100, d_loss=0.637, g_loss=0.886
# epoch = 78/100, d_loss=0.675, g_loss=0.863
# epoch = 79/100, d_loss=0.662, g_loss=0.848
# epoch = 80/100, d_loss=0.656, g_loss=0.901
# epoch = 81/100, d_loss=0.660, g_loss=0.880
# epoch = 82/100, d_loss=0.645, g_loss=0.929
# epoch = 83/100, d_loss=0.657, g_loss=0.859
# epoch = 84/100, d_loss=0.614, g_loss=0.897
# epoch = 85/100, d_loss=0.720, g_loss=0.889
# epoch = 86/100, d_loss=0.647, g_loss=0.897
# epoch = 87/100, d_loss=0.650, g_loss=0.916
# epoch = 88/100, d_loss=0.625, g_loss=0.852
# epoch = 89/100, d_loss=0.619, g_loss=0.878
# epoch = 90/100, d_loss=0.662, g_loss=0.907
# epoch = 91/100, d_loss=0.641, g_loss=0.887
# epoch = 92/100, d_loss=0.645, g_loss=0.877
# epoch = 93/100, d_loss=0.641, g_loss=0.873
# epoch = 94/100, d_loss=0.679, g_loss=0.835
# epoch = 95/100, d_loss=0.594, g_loss=0.902
# epoch = 96/100, d_loss=0.628, g_loss=0.880
# epoch = 97/100, d_loss=0.654, g_loss=0.889
# epoch = 98/100, d_loss=0.646, g_loss=0.904
# epoch = 99/100, d_loss=0.646, g_loss=0.862
# epoch = 100/100, d_loss=0.629, g_loss=0.968
# epoch = 101/100, d_loss=0.674, g_loss=0.887

# %% [markdown]
# ### 5. Evaluate model

# %%
# plotting the metrics
plt.plot(d_loss)
plt.plot(d_g_loss)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Discriminator', 'Adversarial'], loc='center right')
plt.show()

# %%
d_g.save("cgan_trained.model")
# Out:
# INFO:tensorflow:Assets written to: cgan_trained.model\assets

# %%
import tensorflowjs as tfjs
tfjs.converters.save_keras_model(d_g, "tfjs_cgan_model")

# %%
generator.save("cgan_generator_trained.model")
import tensorflowjs as tfjs
tfjs.converters.save_keras_model(generator, "tfjs_cgan_generator_model")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: cgan_generator_trained.model\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
